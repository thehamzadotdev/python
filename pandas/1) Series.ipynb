# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Series

# %%
arr = [10,20,30]
pd.Series(arr)
d= {"a":10, "b":20, "c":30}
pd.Series(d)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %% [markdown]
# ## Creating a dataframe
