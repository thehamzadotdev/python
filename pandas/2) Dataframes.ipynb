# %%
import numpy as np 
import pandas as pd

# %% [markdown]
# ## Creating a dataframe

# %%
data = {
    'Name': ['John', 'Anna', 'Peter', 'Linda'],
    'Age': [28, 34, 29, 42],
    'City': ['New York', 'Paris', 'Berlin', 'London'],
    'Salary': [65000, 70000, 62000, 85000]
}
df = pd.DataFrame(data)
df
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
# List
data_list = [
    ['John', 28, 'New York', 65000],
    ['Anna', 34, 'Paris', 70000],
    ['Peter', 29, 'Berlin', 62000],
    ['Linda', 42, 'London', 85000]
]
df = pd.DataFrame(data_list)
columns = ["Name","Age","City","Salary"]
df = pd.DataFrame(data_list, columns=columns)
df
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %% [markdown]
# ## Selection and indexing of coulmn

# %%
df['Salary']
# Out:
# 0    65000
# 1    70000
# 2    62000
# 3    85000
# Name: Salary, dtype: int64

# %%
# selecting multiple coulmns
df[["Name", "Salary"]]
# Out:
#     Name  Salary
# 0   John   65000
# 1   Anna   70000
# 2  Peter   62000
# 3  Linda   85000

# %% [markdown]
# ## Creating a new coulmn

# %%
df["Designation"] = ["Engr", "Doctor", "Captian", "Banker"]
df
# Out:
#     Name  Age      City  Salary Designation
# 0   John   28  New York   65000        Engr
# 1   Anna   34     Paris   70000      Doctor
# 2  Peter   29    Berlin   62000     Captian
# 3  Linda   42    London   85000      Banker

# %% [markdown]
# ## Removing a coulmn

# %%
df.drop("Designation", axis=1, inplace=True)

# %%
df
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %% [markdown]
# ## Selecting a row

# %%
df
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
df.loc[[0,1]]
# Out:
#    Name  Age      City  Salary
# 0  John   28  New York   65000
# 1  Anna   34     Paris   70000

# %% [markdown]
# ## Selecting a subset rows and coulmn

# %%
df.loc[[0,3]][["City", "Salary"]]
# Out:
#        City  Salary
# 0  New York   65000
# 3    London   85000

# %% [markdown]
# ## Conditional selction

# %%
df[df['Age']> 30]
# Out:
#     Name  Age    City  Salary
# 1   Anna   34   Paris   70000
# 3  Linda   42  London   85000

# %%
df[(df['Age']> 30) & (df['City'] == "Paris")]
# Out:
#    Name  Age   City  Salary
# 1  Anna   34  Paris   70000
