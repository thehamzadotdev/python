# %%
import numpy as np 
import pandas as pd

# %%
df = pd.read_csv("odb.csv")
df
# Out:
#      Unnamed: 0                   Player       Span  Mat  Inns  NO   Runs  \
# 0             0     SR Tendulkar (INDIA)  1989-2012  463   452  41  18426
# 1             1          V Kohli (INDIA)  2008-2021  254   245  39  12169
# 2             2     RT Ponting (AUS/ICC)  1995-2012  375   365  39  13704
# 3             3        RG Sharma (INDIA)  2007-2021  227   220  32   9205
# 4             4  ST Jayasuriya (Asia/SL)  1989-2011  445   433  18  13430
# ..          ...                      ...        ...  ...   ...  ..    ...
# 114         114         SK Raina (INDIA)  2005-2018  226   194  35   5615
# 115         115        H Masakadza (ZIM)  2001-2019  209   208   4   5658
# 116         116       RB Richardson (WI)  1983-1996  224   217  30   6248
# 117         117         BB McCullum (NZ)  2002-2016  260   228  28   6083
# 118         118       Saleem Malik (PAK)  1982-1999  283   256  38   7170
#
#        HS    Ave     BF     SR  100  50   0    4s   6s
# ...

# %%
df[df['Ave']> 50]
# Out:
#     Unnamed: 0                   Player       Span  Mat  Inns  NO   Runs  \
# 1            1          V Kohli (INDIA)  2008-2021  254   245  39  12169
# 6            6  AB de Villiers (Afr/SA)  2005-2018  228   218  39   9577
# 23          23            JE Root (ENG)  2013-2021  152   142  23   6109
# 30          30         Babar Azam (PAK)  2015-2021   83    81  11   3985
# 51          51             SD Hope (WI)  2016-2021   83    78  10   3599
# 56          56    MS Dhoni (Asia/INDIA)  2004-2019  350   297  84  10773
# 94          94           MG Bevan (AUS)  1994-2004  232   196  67   6912
# 97          97   RN ten Doeschate (NED)  2006-2011   33    32   9   1541
#
#       HS    Ave     BF      SR  100  50   0    4s   6s
# 1    183  59.07  13061   93.17   43  62  13  1140  125
# 6    176  53.50   9473  101.09   25  53   7   840  204
# 23  133*  51.33   7034   86.84   16  35   5   491   44
# 30   158  56.92   4449   89.57   14  17   3   360   41
# ...

# %%
df[(df['Ave']> 50) & (df['SR']> 100)]
# Out:
#    Unnamed: 0                   Player       Span  Mat  Inns  NO  Runs   HS  \
# 6           6  AB de Villiers (Afr/SA)  2005-2018  228   218  39  9577  176
#
#     Ave    BF      SR  100  50  0   4s   6s
# 6  53.5  9473  101.09   25  53  7  840  204

# %%
df.isna().sum()
# Out:
# Unnamed: 0    0
# Player        0
# Span          0
# Mat           0
# Inns          0
# NO            0
# Runs          0
# HS            0
# Ave           0
# BF            0
# SR            0
# 100           0
# 50            0
# 0             0
# 4s            0
# 6s            0
# dtype: int64
